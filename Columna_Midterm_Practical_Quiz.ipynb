# %% [markdown]
# <a href="https://colab.research.google.com/github/EarvinColumna/CpE-AIDA-Lab-02/blob/main/Columna_Midterm_Practical_Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Columna, Earvin Deejay P.
# ##Student Number: 201813280
# ## Section: 58051

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as pdr
from scipy import stats
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ####1. Read the dataset in xls file.

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-c10f97dc-4730-4f67-b4c7-8d0e61600974" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c10f97dc-4730-4f67-b4c7-8d0e61600974">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ####2. Clean the data if not yet cleaned.

# %%
pm = pd.read_excel('pokemon.xlsx') 
pm
# Out:
#           #           Name            Type  Total   HP  Attack  Defense  \
# 0       001      Bulbasaur   GRASS, POISON    318   45      49       49
# 1       002        Ivysaur   GRASS, POISON    405   60      62       63
# 2       003       Venusaur   GRASS, POISON    525   80      82       83
# 3     003.1  Mega Venusaur   GRASS, POISON    625   80     100      123
# 4       004     Charmander            FIRE    309   39      52       43
# ..      ...            ...             ...    ...  ...     ...      ...
# 768     714         Noibat  FLYING, DRAGON    245   40      30       35
# 769     715        Noivern  FLYING, DRAGON    535   85      70       80
# 770     716        Xerneas           FAIRY    680  126     131       95
# 771     717        Yveltal    DARK, FLYING    680  126     131       95
# 772     718        Zygarde  DRAGON, GROUND    600  108     100      121
#
#      Special Attack  Special Defense  Speed
# 0                65               65     45
# ...

# %% [markdown]
# ####3. Create a python program that will show the descriptive analysis of the datasets ( Count, min, max, standard deviation, 75%,50%and 25%)

# %%
pm.describe()
# Out:
#             Total          HP      Attack     Defense  Special Attack  \
# count  773.000000  773.000000  773.000000  773.000000      773.000000
# mean   428.206986   68.931436   77.318241   72.552393       71.182406
# std    115.570677   25.754605   31.176825   30.114400       31.236588
# min    180.000000    1.000000    5.000000    5.000000       10.000000
# 25%    328.000000   50.000000   55.000000   50.000000       47.000000
# 50%    440.000000   65.000000   75.000000   70.000000       65.000000
# 75%    505.000000   80.000000   95.000000   90.000000       91.000000
# max    780.000000  255.000000  190.000000  230.000000      194.000000
#
#        Special Defense       Speed
# count       773.000000  773.000000
# mean         70.626132   67.596378
# std          27.222670   28.511657
# min          20.000000    5.000000
# 25%          50.000000   45.000000
# 50%          66.000000   65.000000
# 75%          86.000000   90.000000
# max         230.000000  180.000000

# %% [markdown]
# ####4. Draw a scatter plot.

# %%
plt.scatter(pm['Attack'], pm ['Defense'], color = 'orange')
plt.xlabel('Attack');
plt.ylabel('Defense');
plt.grid()
plt.show()
X = pm['Attack']
Y = pm['Defense']

# %% [markdown]
# ####5. Create a python program that will plot and show the regression line and regression coefficient.

# %%
def myfunc(X):
  return slope *X + intercept
slope, intercept, r, p, std_err = stats.linregress(X,Y)
mod = list(map(myfunc, X))

# %%
plt.scatter(X, Y, color = 'orange')
plt.plot(X, mod)
plt.grid()
plt.show()

# %% [markdown]
# ####6. Create a python code to predict future values. Is linear regression the appropriate method to use to predict future values? Why?

# %%
import seaborn as sns
df = pd.DataFrame(pm,columns=['Total','HP','Attack','Defense','Special Attack','Special Defense','Speed'])
corrMatrix = df.corr()
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.heatmap(corrMatrix, annot=True)
plt.xlabel('Correlations between features')
plt.show()
